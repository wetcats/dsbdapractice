# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("dataset_Facebook.csv", sep=";")

# %%
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %% [markdown]
# # Data Subsets

# %%
a = df.iloc[:,:4]
a.reset_index(inplace=True)
a
# Out:
#      index  Page total likes    Type  Category  Post Month
# 0        0            139441   Photo         2          12
# 1        1            139441  Status         2          12
# 2        2            139441   Photo         3          12
# 3        3            139441   Photo         2          12
# 4        4            139441   Photo         2          12
# ..     ...               ...     ...       ...         ...
# 495    495             85093   Photo         3           1
# 496    496             81370   Photo         2           1
# 497    497             81370   Photo         1           1
# 498    498             81370   Photo         3           1
# 499    499             81370   Photo         2           1
#
# [500 rows x 5 columns]

# %%
b = df.iloc[:,-4:]
b.reset_index(inplace=True)

# %% [markdown]
# # Merge Data

# %%
df_concat = pd.concat([a,b], axis=1)
df_concat
# Out:
#      Page total likes    Type  Category  Post Month  comment    like  share  \
# 0              139441   Photo         2          12        4    79.0   17.0
# 1              139441  Status         2          12        5   130.0   29.0
# 2              139441   Photo         3          12        0    66.0   14.0
# 3              139441   Photo         2          12       58  1572.0  147.0
# 4              139441   Photo         2          12       19   325.0   49.0
# ..                ...     ...       ...         ...      ...     ...    ...
# 495             85093   Photo         3           1        5    53.0   26.0
# 496             81370   Photo         2           1        0    53.0   22.0
# 497             81370   Photo         1           1        4    93.0   18.0
# 498             81370   Photo         3           1        7    91.0   38.0
# 499             81370   Photo         2           1        0    91.0   28.0
#
#      Total Interactions
# 0                   100
# ...

# %%
pd.merge(a,b, on='index')
# Out:
#      index  Page total likes    Type  Category  Post Month  comment    like  \
# 0        0            139441   Photo         2          12        4    79.0
# 1        1            139441  Status         2          12        5   130.0
# 2        2            139441   Photo         3          12        0    66.0
# 3        3            139441   Photo         2          12       58  1572.0
# 4        4            139441   Photo         2          12       19   325.0
# ..     ...               ...     ...       ...         ...      ...     ...
# 495    495             85093   Photo         3           1        5    53.0
# 496    496             81370   Photo         2           1        0    53.0
# 497    497             81370   Photo         1           1        4    93.0
# 498    498             81370   Photo         3           1        7    91.0
# 499    499             81370   Photo         2           1        0    91.0
#
#      share  Total Interactions
# ...

# %% [markdown]
# # Sort Data

# %%
df_concat.sort_values("like", ascending=False)
# Out:
#      Page total likes   Type  Category  Post Month  comment    like  share  \
# 244            130791  Photo         2           7      372  5172.0  790.0
# 379            111620  Photo         3           4       51  1998.0  128.0
# 349            117764  Photo         3           5       45  1639.0  122.0
# 168            135428  Photo         1           9      144  1622.0  208.0
# 3              139441  Photo         2          12       58  1572.0  147.0
# ..                ...    ...       ...         ...      ...     ...    ...
# 21             138414  Photo         1          12        0     0.0    0.0
# 100            137020  Photo         1          10        0     0.0    0.0
# 441             98195  Photo         1           3        0     0.0    0.0
# 417            104070  Photo         1           3        0     0.0    0.0
# 111            136736  Photo         1          10        0     NaN    NaN
#
#      Total Interactions
# 244                6334
# ...

# %% [markdown]
# # Transpose Data

# %%
df_concat.iloc[:10,:].T
# Out:
#                          0       1       2       3       4       5       6  \
# Page total likes    139441  139441  139441  139441  139441  139441  139441
# Type                 Photo  Status   Photo   Photo   Photo  Status   Photo
# Category                 2       2       3       2       2       2       3
# Post Month              12      12      12      12      12      12      12
# comment                  4       5       0      58      19       1       3
# like                  79.0   130.0    66.0  1572.0   325.0   152.0   249.0
# share                 17.0    29.0    14.0   147.0    49.0    33.0    27.0
# Total Interactions     100     164      80    1777     393     186     279
#
#                          7       8       9
# Page total likes    139441  139441  139441
# Type                 Photo  Status   Photo
# Category                 3       2       3
# Post Month              12      12      12
# comment                  0       0       3
# ...

# %%
df_concat.iloc[:1,:].T
# Out:
#                          0
# Page total likes    139441
# Type                 Photo
# Category                 2
# Post Month              12
# comment                  4
# like                  79.0
# share                 17.0
# Total Interactions     100

# %% [markdown]
# # Data Shape and Reshape
#
# > **DataFrame.pivot()** is a method in pandas that is used when we need to reorder or reshape the given DataFrame according to index and column values for a better understanding of datasets and to analyze the data according to our compatibility.It is used for rearranging the DataFrame without applying aggregation. It does not contain duplicate values.
#
# **DataFrame.pivot(
#     index=None,
#     columns=None,
#     values=None)**
#
# >**DataFrame.pivot_table()** method is used to pivot the DataFrame by applying aggregation on it and it allows duplicate values or columns/indexes.
#
# **DataFrame.pivot_table(
#     values=None,
#     index=None,
#     columns=None,
#     aggfunc='mean',
#     fill_value=None,
#     margins=False,
#     dropna=True,
#     margins_name='All',
#     observed=False,
#     sort=True
#     )**
#
# ----
#
# `Difference`
#
# *The DataFrame.pivot_table() is nothing but a generalization form of DataFrame.pivot(). We can pass a function inside DataFrame.pivot_table() method. DataFrame.Pivot_table() also accepts the list of indices whereas DataFrame.pivot() does not.*

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#    index  Page total likes    Type  Category  Post Month  Post Weekday  \
# 0      0            139441   Photo         2          12             4
# 1      1            139441  Status         2          12             3
# 2      2            139441   Photo         3          12             3
# 3      3            139441   Photo         2          12             2
# 4      4            139441   Photo         2          12             2
#
#    Post Hour  Paid  Lifetime Post Total Reach  \
# 0          3   0.0                       2752
# 1         10   0.0                      10460
# 2          3   0.0                       2413
# 3         10   1.0                      50128
# 4          3   0.0                       7244
#
#    Lifetime Post Total Impressions  Lifetime Engaged Users  \
# 0                             5091                     178
# 1                            19057                    1457
# 2                             4373                     177
# ...

# %%
pivot = df.pivot(index="index", columns=["Type"], values=["Lifetime Post Impressions by people who have liked your Page"])
pivot
# Out:
#       Lifetime Post Impressions by people who have liked your Page           \
# Type                                                          Link    Photo
# index
# 0                                                    NaN             3078.0
# 1                                                    NaN                NaN
# 2                                                    NaN             2812.0
# 3                                                    NaN            61027.0
# 4                                                    NaN             6228.0
# ...                                                  ...                ...
# 495                                                  NaN             4750.0
# 496                                                  NaN             3961.0
# 497                                                  NaN             4742.0
# 498                                                  NaN             4534.0
# ...

# %%
pivot_table = pd.pivot_table(df,index=['Type'],columns=["Category"], values='like', aggfunc='mean')
pivot_table
# Out:
# Category           1           2           3
# Type
# Link       75.650000   32.000000   68.000000
# Photo     126.000000  235.857143  219.753333
# Status    136.333333  182.552632  151.500000
# Video     231.428571         NaN         NaN
